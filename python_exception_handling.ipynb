# %% [markdown]
# # Python Exception Handling
#
# ---

# %% [markdown]
# ## Problem 1: Division by Zero (ZeroDivisionError)
#
# **Problem:** Divide two numbers entered by the user.
#
# **Approach:** Try dividing numbers and observe the error.

# %%
#write your answer here

a = int(input())
b = int(input())
print(a/b)
# Out:
# 2.0

# %%
#write with exception handling(use try catch block)
try:
    a = int(input())
    b = int(input())
    print(a/b)
except:
    print("Zero Division Error")
# Out:
# 2.5

# %% [markdown]
# ## Problem 2: Invalid Input (ValueError)
#
# **Problem:** Convert user input into an integer.
#
# **Approach:** Enter text instead of number to see the error.

# %%
#write your answer here
num = int(input())
print(num)
# Out:
# 5

# %%
#write with exception handling(use try catch block)
try:
    a = int(input())
    b = int(input())
    print(a/b)
except ValueError:
    print("enter numbers only")
# Out:
# enter numbers only

# %% [markdown]
# ## Problem 3: List Index Error (IndexError)
#
# **Problem:** Access invalid index in a list.

# %%
#write your answer here
l = [1,2,3,4,5]
print(l[3])
# Out:
# 4

# %%
#write with exception handling(use try catch block)
try:
    l = [1,2,3,4,5]
    print(l[7])
except IndexError:
    print("Enter valid index")
# Out:
# Enter valid index

# %% [markdown]
# ## Problem 4: Dictionary Key Error (KeyError)
#
# **Problem:** Access missing key from dictionary.

# %%
#write your answer here
x = {"name":"Ankit", "Age":22}
print(x["marks"])

# %%
#write with exception handling(use try catch block)
try:
    x = {"name":"Ankit", "Age":22}
    print(x["marks"])
except KeyError:
    print("Enter valid keyword its not in Dic")
# Out:
# Enter valid keyword its not in Dic

# %% [markdown]
# ## Problem 5: File Not Found (FileNotFoundError)
#
# **Problem:** Try reading a file that does not exist.

# %%
#write your answer here
f = open("C:/Users/ANKIT BHARDWAJ/downloads/Batch_9.txt", "r")
print(f.read())
# Out:
# hello Batch 9
# Ankit Here......

# %%
#write with exception handling(use try catch block)
try:
    f = open("C:/Users/ANKIT BHARDWAJ/Downloads/Batch_9.txt", "r")
    print(f.read())

except FileNotFoundError:
    print("File Not Found")
# Out:
# hello Batch 9
# Ankit Here......
